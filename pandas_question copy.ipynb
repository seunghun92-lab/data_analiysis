# %% [markdown]
# ### **[실습] 기본 실습**
#
# | Name | Age | City | Salary |
# | --- | --- | --- | --- |
# | Alice | 25 | New York | 70000 |
# | Bob | 30 | Los Angeles | 80000 |
# | Charlie | 35 | Chicago | 120000 |
# | David | 40 | Houston | 90000 |
# | Eve | 28 | San Francisco | 75000 |
# - 다음 데이터를 활용하여 실습 문제를 해결하세요.

# %% [markdown]
# DataFrame객체 생성 : 위의 데이터를 사용해 DataFrame객체를 생성하세요.

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, 40, 28],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'San Francisco'],
    'Salary' : [70000, 80000, 120000, 90000, 75000]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %% [markdown]
# 2. **열과 행 선택**
#     - `Name`과 `City` 열을 선택하여 출력하세요.
#     - 나이가 30 이상인 행을 선택하여 출력하세요.

# %%
print(df[['Name', 'City']])

# 특정 열 선택
print(df[df['Age']] >= 30)
# Out:
#       Name         City
# 0    Alice     New York
# 1      Bob  Los Angeles
# 2  Charlie      Chicago
# 3    David      Houston
# 4    Frank      Seattle
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 4
#       1 print(df[['Name', 'City']])
#       3 # 특정 열 선택
# ----> 4 print(df[df['Age']] >= 30)
#
# File c:\data_analysis\data_analysis_venv\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\data_analysis\data_analysis_venv\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\data_analysis\data_analysis_venv\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([25, 30, 35, 40, 33], dtype='int64')] are in the [columns]"

# %% [markdown]
# 3. **행과 열 추가**
#     - `Country` 열을 추가하고, 모두 'USA'로 설정하세요.
#     - 새로운 행을 추가하세요. (Name: Frank, Age: 33, City: Seattle, Salary: 85000)

# %%
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
df['Country'] = ['USA', 'USA', 'USA', 'USA', 'USA']
df
df.loc[4] = ['Frank', 33, 'Seattle', '85000', 'USA']
print(df)
# Out:
#       Name  Age         City  Salary Country
# 0    Alice   25     New York   70000     USA
# 1      Bob   30  Los Angeles   80000     USA
# 2  Charlie   35      Chicago  120000     USA
# 3    David   40      Houston   90000     USA
# 4    Frank   33      Seattle   85000     USA
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_11112\1437075124.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '85000' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[4] = ['Frank', 33, 'Seattle', '85000', 'USA']

# %% [markdown]
# 4. **데이터 삭제**
#     - `Salary` 열을 삭제하세요.
#     - 'David'가 있는 행을 삭제하세요.

# %%
df
# Out:
#       Name  Age         City Country
# 0    Alice   25     New York     USA
# 1      Bob   30  Los Angeles     USA
# 2  Charlie   35      Chicago     USA
# 3    David   40      Houston     USA
# 4    Frank   33      Seattle     USA

# %%
df.drop('Salary', axis=1)
print(df)
df = df.drop('David', axis=0)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.drop('Salary', axis=1)
#       2 print(df)
#       3 df = df.drop('David', axis=0)
#
# File c:\data_analysis\data_analysis_venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\data_analysis\data_analysis_venv\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\data_analysis\data_analysis_venv\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\data_analysis\data_analysis_venv\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Salary'] not found in axis"

# %% [markdown]
# 5. **데이터 수정**
#     - `Age`가 35 이상인 사람들의 `Salary`를 5% 증가시키세요.
#     - 'Alice'의 `City`를 'Boston'으로 수정하세요.

# %%
df_filtered = df[(df['Age'] >= 35) & (df['City'] == 'Boston')]
print(df_filtered)
# Out:
# Empty DataFrame
# Columns: [Name, Age, City, Salary]
# Index: []

# %% [markdown]
# 6. **데이터 타입 변환**
#     - `Age`와 `Salary`의 데이터 타입을 float로 변환하세요.
